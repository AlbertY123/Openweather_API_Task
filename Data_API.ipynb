# %% [markdown]
# # Gathering data using an API

# %% [markdown]
# ## Step 1: Get an API Key
#
# Go to [OpenWeatherMap](https://openweathermap.org/appidand) sign up for a free account.
#
# Once registered, navigate to the API keys section to generate your API key.
#
# Copy the API key—you’ll need it to make requests.

# %% [markdown]
# ## Step 2: Install Required Libraries
#
# To interact with the API, you’ll need the requests library in Python. Install it using pip:
#
# `pip install requests`

# %% [markdown]
# ## Step 3: Make Your First API Request
#
# Let’s start by fetching the current weather for a specific city.

# %%
import requests
import json

# Replace with your API key
API_KEY = '5b8880c4f33c1388efc5c067473947c5'

# API endpoint and parameters
city = 'Melbourne'
url = f'http://api.openweathermap.org/data/2.5/weather?q={city}&appid={API_KEY}&units=metric'

# Make the request
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    data = response.json()  # Parse JSON response
    pretty_json_string = json.dumps(data, indent=4)
    print(pretty_json_string)  # Print the raw data
else:
    print(f"Error: {response.status_code}")
# Out:
# {
#     "coord": {
#         "lon": -80.6081,
#         "lat": 28.0836
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 8.11,
#         "feels_like": 6.19,
#         "temp_min": 6.69,
#         "temp_max": 10.55,
#         "pressure": 1023,
#         "humidity": 53,
#         "sea_level": 1023,
#         "grnd_level": 1023
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3.09,
#         "deg": 300
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1771901898,
#     "sys": {
#         "type": 1,
#         "id": 4922,
#         "country": "US",
#         "sunrise": 1771847593,
#         "sunset": 1771888722
#     },
#     "timezone": -18000,
#     "id": 4163971,
#     "name": "Melbourne",
#     "cod": 200
# }

# %% [markdown]
# ## Step 4: Parse and Use the Data
#
# The API returns data in JSON format. Let’s extract and display some useful information:

# %%
# Extract relevant data
if response.status_code == 200:
    data = response.json()
    city_name = data['name']
    weather_description = data['weather'][0]['description']
    temperature = data['main']['temp']  # Temperature in Kelvin
    humidity = data['main']['humidity']

    # Convert temperature to Celsius
    temperature_celsius = temperature

    # Display the data
    print(f"Weather in {city_name}:")
    print(f"Description: {weather_description}")
    print(f"Temperature: {temperature_celsius:.2f}°C")
    print(f"Humidity: {humidity}%")
# Out:
# Weather in Melbourne:
# Description: clear sky
# Temperature: 8.11°C
# Humidity: 53%

# %% [markdown]
# Exploring Other Endpoints
#
# OpenWeatherMap offers many endpoints. Here are a few examples:
#
# **5-Day Weather Forecast**

# %%
url = f'http://api.openweathermap.org/data/2.5/forecast?q={city}&appid={API_KEY}&units=metric'
lat = 40.4167
lon = 3.7033
#url = f'https://pro.openweathermap.org/data/2.5/forecast/climate?lat={lat}&lon={lon}&appid={API_KEY}'
response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    for forecast in data['list']:
        date = forecast['dt_txt']
        temp = forecast['main']['temp']
        weather = forecast['weather'][0]['description']
        print(f"{date}: {temp:.2f}°C, {weather}")
# Out:
# 2025-08-14 03:00:00: 24.40°C, few clouds
# 2025-08-14 06:00:00: 24.12°C, few clouds
# 2025-08-14 09:00:00: 28.77°C, clear sky
# 2025-08-14 12:00:00: 35.59°C, clear sky
# 2025-08-14 15:00:00: 38.25°C, clear sky
# 2025-08-14 18:00:00: 37.23°C, clear sky
# 2025-08-14 21:00:00: 34.70°C, overcast clouds
# 2025-08-15 00:00:00: 30.98°C, broken clouds
# 2025-08-15 03:00:00: 29.33°C, broken clouds
# 2025-08-15 06:00:00: 27.31°C, scattered clouds
# 2025-08-15 09:00:00: 29.90°C, clear sky
# 2025-08-15 12:00:00: 35.30°C, clear sky
# 2025-08-15 15:00:00: 38.04°C, clear sky
# 2025-08-15 18:00:00: 37.71°C, clear sky
# 2025-08-15 21:00:00: 34.98°C, clear sky
# 2025-08-16 00:00:00: 33.15°C, clear sky
# 2025-08-16 03:00:00: 29.31°C, clear sky
# 2025-08-16 06:00:00: 28.03°C, clear sky
# 2025-08-16 09:00:00: 31.43°C, clear sky
# 2025-08-16 12:00:00: 36.41°C, clear sky
# 2025-08-16 15:00:00: 39.13°C, clear sky
# 2025-08-16 18:00:00: 38.67°C, clear sky
# 2025-08-16 21:00:00: 35.93°C, broken clouds
# ...

# %% [markdown]
# ## Step 5: Save Data to a File
#
# You can save the API response to a file. This is particularly useful when gathering data to train a machine learning model.

# %%
import json

if response.status_code == 200:
    data = response.json()
    with open('weather_data.json', 'w') as file:
        json.dump(data, file, indent=4)
    print("Data saved to weather_data.json")
# Out:
# Data saved to weather_data.json

# %% [markdown]
# # Investigation tasks
#
# **Task 1**: Find out the geographic coordinates of Trinity Grammar Kew and display in separate lines the current temperature, humidity, pressure and wind speed.
#
# <span style="color:red">(1 mark)</span>

# %%
lat = -37.8101391
lon = 145.0322747
url = f'http://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={API_KEY}&units=metric'
response = requests.get(url)

if response.status_code == 200:
    data = response.json()
      # Parse JSON response
    pretty_json_string = json.dumps(data, indent=4)
    print(f'Temperature: {data["main"]["temp"]}°C')
    print(f'Humidity: {data["main"]["humidity"]}%')
    print(f'Pressure: {data["main"]["pressure"]}')
    print(f'Wind Speed: {data["wind"]["speed"]} m/s')
    pass  # Add your code here
# Out:
# Temperature: 20.77°C
# Humidity: 80%
# Pressure: 1011
# Wind Speed: 4.02 m/s

# %% [markdown]
# **Task 2**: Check the OpenWeatherMap pricing page and documentation to find the daily limit for free-tier users. Write a Python script to simulate making requests until you hit the limit.
#
# <span style="color:red">(1 mark)</span>
#
#
# **Task 3**: Try making a request with an invalid city name (e.g., "MiddleEarth") and observe the API’s response. Write code to handle such errors gracefully.
#
# <span style="color:red">(1 mark)</span>
#
# **Task 4**: Write a Python script to fetch and compare current weather data for two cities (e.g., London and New York). Display the results in a user-friendly format.
#
# <span style="color:red">(1 mark)</span>
#
# **Task 5**: What units does the API use for temperature, wind speed, and other measurements by default? Can you change these units?
#
# <span style="color:red">(1 mark)</span>

# %%
# Task 2
import random
for i in range(1001):
    lat = -37.8101391 + random.uniform(-0.5, 0.5)  # Add small random variation to latitude
    lon = 145.0322747 + random.uniform(-0.5, 0.5)  # Add small random variation to longitude
    url = f'http://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={API_KEY}&units=metric'
    response = requests.get(url)
    print(response)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# ...

# %%
# Task 3
import requests
import json

# Replace with your API key
API_KEY = '5b8880c4f33c1388efc5c067473947c5'

# API endpoint and parameters
city = 'Melbour'
url = f'http://api.openweathermap.org/data/2.5/weather?q={city}&appid={API_KEY}&units=metric'

# Make the request
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    data = response.json()  # Parse JSON response
    pretty_json_string = json.dumps(data, indent=4)
    print(pretty_json_string)  # Print the raw data
else:
    print("There was an error with the API request. Please check the city name and try again.")
# Out:
# There was an error with the API request. Please check the city name and try again.

# %%
# Task 4
import requests
import json
import time

# Replace with your API key
API_KEY = '5b8880c4f33c1388efc5c067473947c5'

# API endpoint and parameters
city_1 = input("Enter the first city name: ")
url_1 = f'http://api.openweathermap.org/data/2.5/weather?q={city_1}&appid={API_KEY}&units=metric'

city_2 = input("Enter the second city name: ")
url_2 = f'http://api.openweathermap.org/data/2.5/weather?q={city_2}&appid={API_KEY}&units=metric'

# Make the request
response_city_1 = requests.get(url_1)
response_city_2 = requests.get(url_2)

# Check if the request was successful
if response_city_1.status_code == 200 and response_city_2.status_code == 200:
    data_1 = response_city_1.json()  # Parse JSON response for first city
    data_2 = response_city_2.json()  # Parse JSON response for second city
    
    #Compare weather of 2 city
    print(f"Comparing weather between {city_1} and {city_2}...")
    time.sleep(1)  # Add a delay between comparisons
    #Temperature of cities
    temp_city_1 = data_1['main']['temp']
    temp_city_2 = data_2['main']['temp']
    print(f"Temperature in {city_1}: {temp_city_1:.2f}°C")
    print(f"Temperature in {city_2}: {temp_city_2:.2f}°C")
    if temp_city_1 > temp_city_2:
        print(f"{city_1} is warmer than {city_2} with a temperature of {temp_city_1:.2f}°C compared to {temp_city_2:.2f}°C.")
    elif temp_city_1 < temp_city_2:
        print(f"{city_2} is warmer than {city_1} with a temperature of {temp_city_2:.2f}°C compared to {temp_city_1:.2f}°C.")
    else:
        print(f"Both {city_1} and {city_2} have the same temperature of {temp_city_1:.2f}°C.")
    time.sleep(1)  # Add a delay between comparisons
    #Humidity of cities
    humidity_city_1 = data_1['main']['humidity']
    humidity_city_2 = data_2['main']['humidity']
    
    print(f"Humidity in {city_1}: {humidity_city_1}%")
    print(f"Humidity in {city_2}: {humidity_city_2}%")
    if humidity_city_1 > humidity_city_2:
        print(f"{city_1} is more humid than {city_2} with a humidity of {humidity_city_1}% compared to {humidity_city_2}%.")
    elif humidity_city_1 < humidity_city_2:
        print(f"{city_2} is more humid than {city_1} with a humidity of {humidity_city_2}% compared to {humidity_city_1}%.")
    else:
        print(f"Both {city_1} and {city_2} have the same humidity of {humidity_city_1}%.")

else:
    print("There was an error with the API request. Please check the city name and try again.")
# Out:
# Comparing weather between shanghai and melbourne...
# Temperature in shanghai: 8.92°C
# Temperature in melbourne: 7.51°C
# shanghai is warmer than melbourne with a temperature of 8.92°C compared to 7.51°C.
# Humidity in shanghai: 93%
# Humidity in melbourne: 59%
# shanghai is more humid than melbourne with a humidity of 93% compared to 59%.

# %%
#Task 5
#Default units are given in metric, and can be changed through the units parameter as shown
lat = -37.8101391
lon = 145.0322747
url = f'http://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={API_KEY}&units=imperial'
response = requests.get(url)

if response.status_code == 200:
    data = response.json()  # Parse JSON response
    pretty_json_string = json.dumps(data, indent=4)
    print(f'Temperature: {data["main"]["temp"]}')
    print(f'Humidity: {data["main"]["humidity"]}')
    print(f'Pressure: {data["main"]["pressure"]}')
    print(f'Wind Speed: {data["wind"]["speed"]}')
    pass
# Out:
# Temperature: 69.24
# Humidity: 80
# Pressure: 1011
# Wind Speed: 8.99
